# %% [markdown]
# import pandas as pd
# df = pd.read_csv('C:/Users/jkatralapalli/Anaconda3/Amazon_Orders.csv')
# df.head()

# %%
df.shape

# %%
df = df.fillna(0)

# %%
df.head()
# Out:
#   Order Date             Order ID  \
# 0   01/01/20  113-0193837-9937010
# 1   01/01/20  113-9345037-6806613
# 2   01/01/20  113-9345037-6806613
# 3   01/01/20  113-9345037-6806613
# 4   01/04/20  112-1754485-0843454
#
#                                                Title     Category   ASIN/ISBN  \
# 0  UNITERS 5yr Furniture Protection (Desks and Ta...         DESK  B07JJ7SX83
# 1  Lipper International 8876 Bamboo Wood Flatware...        CADDY  B002JM0RNC
# 2  VASAGLE ALINRU Nightstand, Stackable End Table...        TABLE  B0783PDVTH
# 3  Resin Lord Sai Baba Statue Car Dashboard Décor...     FIGURINE  B01G6U73TS
# 4  Friencity Bluetooth V5.0 Transmitter and Recei...  AV_RECEIVER  B0793ZT129
#
#    UNSPSC Code     Website Release Date Condition           Seller  ...  \
# 0     56101700  Amazon.com            0       new          UNITERS  ...
# 1     52150000  Amazon.com            0       new       Amazon.com  ...
# ...

# %%
df["Item Total"] = df["Item Total"].str.replace('$','').astype(float)
df["Item Subtotal Tax"] = df["Item Subtotal Tax"].str.replace('$','').astype(float)
df["Item Subtotal"] = df["Item Subtotal"].str.replace('$','').astype(float)
df.head()
# Out:
#   Order Date             Order ID  \
# 0   01/01/20  113-0193837-9937010
# 1   01/01/20  113-9345037-6806613
# 2   01/01/20  113-9345037-6806613
# 3   01/01/20  113-9345037-6806613
# 4   01/04/20  112-1754485-0843454
#
#                                                Title     Category   ASIN/ISBN  \
# 0  UNITERS 5yr Furniture Protection (Desks and Ta...         DESK  B07JJ7SX83
# 1  Lipper International 8876 Bamboo Wood Flatware...        CADDY  B002JM0RNC
# 2  VASAGLE ALINRU Nightstand, Stackable End Table...        TABLE  B0783PDVTH
# 3  Resin Lord Sai Baba Statue Car Dashboard Décor...     FIGURINE  B01G6U73TS
# 4  Friencity Bluetooth V5.0 Transmitter and Recei...  AV_RECEIVER  B0793ZT129
#
#    UNSPSC Code     Website Release Date Condition           Seller  ...  \
# 0     56101700  Amazon.com            0       new          UNITERS  ...
# 1     52150000  Amazon.com            0       new       Amazon.com  ...
# ...

# %%
df["Item Total"].sum()
# Out:
# 4107.820000000001

# %%
df["Item Total"].mean()
# Out:
# 17.40601694915248

# %%
df["Item Total"].median()
# Out:
# 3.99

# %%
df["Item Total"].max()
# Out:
# 707.41

# %%
df["Item Total"].min()
# Out:
# 0.0

# %%
df["Item Subtotal Tax"].sum()
# Out:
# 273.06999999999994

# %%
df["Item Total"].sum()/df["Item Subtotal Tax"].sum()
# Out:
# 15.043102501190177

# %%
df["Item Subtotal Tax"].sum()/df["Item Total"].sum()
# Out:
# 0.06647564888432304

# %%
df["Order Date"] = pd.to_datetime(df['Order Date'])
df.head()
# Out:
#   Order Date             Order ID  \
# 0 2020-01-01  113-0193837-9937010
# 1 2020-01-01  113-9345037-6806613
# 2 2020-01-01  113-9345037-6806613
# 3 2020-01-01  113-9345037-6806613
# 4 2020-01-04  112-1754485-0843454
#
#                                                Title     Category   ASIN/ISBN  \
# 0  UNITERS 5yr Furniture Protection (Desks and Ta...         DESK  B07JJ7SX83
# 1  Lipper International 8876 Bamboo Wood Flatware...        CADDY  B002JM0RNC
# 2  VASAGLE ALINRU Nightstand, Stackable End Table...        TABLE  B0783PDVTH
# 3  Resin Lord Sai Baba Statue Car Dashboard Décor...     FIGURINE  B01G6U73TS
# 4  Friencity Bluetooth V5.0 Transmitter and Recei...  AV_RECEIVER  B0793ZT129
#
#    UNSPSC Code     Website Release Date Condition           Seller  ...  \
# 0     56101700  Amazon.com            0       new          UNITERS  ...
# 1     52150000  Amazon.com            0       new       Amazon.com  ...
# ...

# %%
df.head(10)
# Out:
#   Order Date             Order ID  \
# 0 2020-01-01  113-0193837-9937010
# 1 2020-01-01  113-9345037-6806613
# 2 2020-01-01  113-9345037-6806613
# 3 2020-01-01  113-9345037-6806613
# 4 2020-01-04  112-1754485-0843454
# 5 2020-01-06  113-4591992-9572218
# 6 2020-01-06  113-4591992-9572218
# 7 2020-01-07  113-1262203-4130604
# 8 2020-01-08  113-1148253-8077824
# 9 2020-01-08  113-3536257-5663406
#
#                                                Title  \
# 0  UNITERS 5yr Furniture Protection (Desks and Ta...
# 1  Lipper International 8876 Bamboo Wood Flatware...
# 2  VASAGLE ALINRU Nightstand, Stackable End Table...
# 3  Resin Lord Sai Baba Statue Car Dashboard Décor...
# 4  Friencity Bluetooth V5.0 Transmitter and Recei...
# 5   Belkin 6-Outlet Power Strip With 3ft Cord, White
# 6  Laptop Table Stand Adjustable Riser: Portable ...
# 7  seenda Wireless Mouse, 2.4G Noiseless Mouse wi...
# 8   Belkin 6-Outlet Power Strip With 3ft Cord, White
# ...

# %%
# %matplotlib inline

# %%
df.plot.bar(x = 'Order Date', y = 'Item Total', rot=90, figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
df1 = df.head(5) #debug

# %%
# Out:
# <ipython-input-64-5d9178dd5c84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Order Date"] = pd.to_datetime(df['Order Date']).dt.date

# %%
df1.shape #debug why the plot is not good
# Out:
# (5, 36)

# %%
df1.plot.bar(x = 'Order Date', y = 'Item Total', rot = 90) #debug
# Out:
# <AxesSubplot:xlabel='Order Date'>

# %%
df["Order Date"] #debug
# Out:
# 0     2020-01-01
# 1     2020-01-01
# 2     2020-01-01
# 3     2020-01-01
# 4     2020-01-04
#          ...
# 231   2020-12-12
# 232   2020-12-12
# 233   2020-12-12
# 234   2020-12-12
# 235   2020-12-12
# Name: Order Date, Length: 236, dtype: datetime64[ns]

# %%
daily_orders = df.groupby('Order Date').sum()["Item Total"] #series not a dataframe.Groups based on indexes in the dataframe
daily_orders.head()
# Out:
# Order Date
# 2020-01-01    172.30
# 2020-01-04     27.24
# 2020-01-06     56.53
# 2020-01-07      9.80
# 2020-01-08     27.23
# Name: Item Total, dtype: float64

# %%
daily_orders.plot.bar(figsize=(20,10), color = '#61D199')
# Out:
# <AxesSubplot:xlabel='Order Date'>
